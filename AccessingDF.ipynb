# %%
pip install mitreattack-python
# Out:
# Requirement already satisfied: mitreattack-python in c:\users\acer\downloads\linking-main (1)\linking-main\.venv\lib\site-packages (3.0.8)
# Requirement already satisfied: colour in c:\users\acer\downloads\linking-main (1)\linking-main\.venv\lib\site-packages (from mitreattack-python) (0.1.5)
# Requirement already satisfied: deepdiff in c:\users\acer\downloads\linking-main (1)\linking-main\.venv\lib\site-packages (from mitreattack-python) (8.2.0)
# Requirement already satisfied: drawsvg>=2.0.0 in c:\users\acer\downloads\linking-main (1)\linking-main\.venv\lib\site-packages (from mitreattack-python) (2.4.0)
# Requirement already satisfied: loguru in c:\users\acer\downloads\linking-main (1)\linking-main\.venv\lib\site-packages (from mitreattack-python) (0.7.3)
# Requirement already satisfied: Markdown in c:\users\acer\downloads\linking-main (1)\linking-main\.venv\lib\site-packages (from mitreattack-python) (3.7)
# Requirement already satisfied: numpy in c:\users\acer\downloads\linking-main (1)\linking-main\.venv\lib\site-packages (from mitreattack-python) (2.2.3)
# Requirement already satisfied: openpyxl in c:\users\acer\downloads\linking-main (1)\linking-main\.venv\lib\site-packages (from mitreattack-python) (3.1.5)
# Requirement already satisfied: pandas in c:\users\acer\downloads\linking-main (1)\linking-main\.venv\lib\site-packages (from mitreattack-python) (2.2.3)
# Requirement already satisfied: pooch in c:\users\acer\downloads\linking-main (1)\linking-main\.venv\lib\site-packages (from mitreattack-python) (1.8.2)
# Requirement already satisfied: python-dateutil in c:\users\acer\downloads\linking-main (1)\linking-main\.venv\lib\site-packages (from mitreattack-python) (2.9.0.post0)
# Requirement already satisfied: Pillow in c:\users\acer\downloads\linking-main (1)\linking-main\.venv\lib\site-packages (from mitreattack-python) (11.1.0)
# Requirement already satisfied: requests in c:\users\acer\downloads\linking-main (1)\linking-main\.venv\lib\site-packages (from mitreattack-python) (2.32.3)
# Requirement already satisfied: rich in c:\users\acer\downloads\linking-main (1)\linking-main\.venv\lib\site-packages (from mitreattack-python) (13.9.4)
# Requirement already satisfied: stix2 in c:\users\acer\downloads\linking-main (1)\linking-main\.venv\lib\site-packages (from mitreattack-python) (3.0.1)
# Requirement already satisfied: stix2-elevator in c:\users\acer\downloads\linking-main (1)\linking-main\.venv\lib\site-packages (from mitreattack-python) (4.1.7)
# Requirement already satisfied: tabulate in c:\users\acer\downloads\linking-main (1)\linking-main\.venv\lib\site-packages (from mitreattack-python) (0.9.0)
# Requirement already satisfied: taxii2-client in c:\users\acer\downloads\linking-main (1)\linking-main\.venv\lib\site-packages (from mitreattack-python) (2.3.0)
# Requirement already satisfied: tqdm in c:\users\acer\downloads\linking-main (1)\linking-main\.venv\lib\site-packages (from mitreattack-python) (4.67.1)
# Requirement already satisfied: typer in c:\users\acer\downloads\linking-main (1)\linking-main\.venv\lib\site-packages (from mitreattack-python) (0.15.1)
# Requirement already satisfied: xlsxwriter in c:\users\acer\downloads\linking-main (1)\linking-main\.venv\lib\site-packages (from mitreattack-python) (3.2.2)
# Requirement already satisfied: orderly-set<6,>=5.3.0 in c:\users\acer\downloads\linking-main (1)\linking-main\.venv\lib\site-packages (from deepdiff->mitreattack-python) (5.3.0)
# Requirement already satisfied: colorama>=0.3.4 in c:\users\acer\downloads\linking-main (1)\linking-main\.venv\lib\site-packages (from loguru->mitreattack-python) (0.4.6)
# Requirement already satisfied: win32-setctime>=1.0.0 in c:\users\acer\downloads\linking-main (1)\linking-main\.venv\lib\site-packages (from loguru->mitreattack-python) (1.2.0)
# Requirement already satisfied: et-xmlfile in c:\users\acer\downloads\linking-main (1)\linking-main\.venv\lib\site-packages (from openpyxl->mitreattack-python) (2.0.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\acer\downloads\linking-main (1)\linking-main\.venv\lib\site-packages (from pandas->mitreattack-python) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\acer\downloads\linking-main (1)\linking-main\.venv\lib\site-packages (from pandas->mitreattack-python) (2025.1)
# Requirement already satisfied: six>=1.5 in c:\users\acer\downloads\linking-main (1)\linking-main\.venv\lib\site-packages (from python-dateutil->mitreattack-python) (1.17.0)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\acer\downloads\linking-main (1)\linking-main\.venv\lib\site-packages (from pooch->mitreattack-python) (4.3.6)
# Requirement already satisfied: packaging>=20.0 in c:\users\acer\downloads\linking-main (1)\linking-main\.venv\lib\site-packages (from pooch->mitreattack-python) (24.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\acer\downloads\linking-main (1)\linking-main\.venv\lib\site-packages (from requests->mitreattack-python) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\acer\downloads\linking-main (1)\linking-main\.venv\lib\site-packages (from requests->mitreattack-python) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\acer\downloads\linking-main (1)\linking-main\.venv\lib\site-packages (from requests->mitreattack-python) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\acer\downloads\linking-main (1)\linking-main\.venv\lib\site-packages (from requests->mitreattack-python) (2025.1.31)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\acer\downloads\linking-main (1)\linking-main\.venv\lib\site-packages (from rich->mitreattack-python) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\acer\downloads\linking-main (1)\linking-main\.venv\lib\site-packages (from rich->mitreattack-python) (2.19.1)
# Requirement already satisfied: simplejson in c:\users\acer\downloads\linking-main (1)\linking-main\.venv\lib\site-packages (from stix2->mitreattack-python) (3.20.1)
# Requirement already satisfied: stix2-patterns>=1.2.0 in c:\users\acer\downloads\linking-main (1)\linking-main\.venv\lib\site-packages (from stix2->mitreattack-python) (2.0.0)
# Requirement already satisfied: maec in c:\users\acer\downloads\linking-main (1)\linking-main\.venv\lib\site-packages (from stix2-elevator->mitreattack-python) (4.1.0.17)
# Requirement already satisfied: netaddr in c:\users\acer\downloads\linking-main (1)\linking-main\.venv\lib\site-packages (from stix2-elevator->mitreattack-python) (1.3.0)
# Requirement already satisfied: pycountry>=20.7.0 in c:\users\acer\downloads\linking-main (1)\linking-main\.venv\lib\site-packages (from stix2-elevator->mitreattack-python) (24.6.1)
# Requirement already satisfied: pluralizer in c:\users\acer\downloads\linking-main (1)\linking-main\.venv\lib\site-packages (from stix2-elevator->mitreattack-python) (1.2.0)
# Requirement already satisfied: stix<1.2.1.0,>=1.1.1.9 in c:\users\acer\downloads\linking-main (1)\linking-main\.venv\lib\site-packages (from stix2-elevator->mitreattack-python) (1.2.0.11)
# Requirement already satisfied: stix2-validator>=3.0.0 in c:\users\acer\downloads\linking-main (1)\linking-main\.venv\lib\site-packages (from stix2-elevator->mitreattack-python) (3.2.0)
# Requirement already satisfied: stixmarx>=1.0.8 in c:\users\acer\downloads\linking-main (1)\linking-main\.venv\lib\site-packages (from stix2-elevator->mitreattack-python) (1.0.8)
# Requirement already satisfied: click>=8.0.0 in c:\users\acer\downloads\linking-main (1)\linking-main\.venv\lib\site-packages (from typer->mitreattack-python) (8.1.8)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\acer\downloads\linking-main (1)\linking-main\.venv\lib\site-packages (from typer->mitreattack-python) (4.12.2)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\acer\downloads\linking-main (1)\linking-main\.venv\lib\site-packages (from typer->mitreattack-python) (1.5.4)
# Requirement already satisfied: mdurl~=0.1 in c:\users\acer\downloads\linking-main (1)\linking-main\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich->mitreattack-python) (0.1.2)
# Requirement already satisfied: mixbox>=1.0.4 in c:\users\acer\downloads\linking-main (1)\linking-main\.venv\lib\site-packages (from stix<1.2.1.0,>=1.1.1.9->stix2-elevator->mitreattack-python) (1.0.5)
# Requirement already satisfied: cybox<2.1.1.0,>=2.1.0.13 in c:\users\acer\downloads\linking-main (1)\linking-main\.venv\lib\site-packages (from stix<1.2.1.0,>=1.1.1.9->stix2-elevator->mitreattack-python) (2.1.0.21)
# Requirement already satisfied: lxml>=2.2.3 in c:\users\acer\downloads\linking-main (1)\linking-main\.venv\lib\site-packages (from stix<1.2.1.0,>=1.1.1.9->stix2-elevator->mitreattack-python) (5.3.1)
# Requirement already satisfied: antlr4-python3-runtime~=4.9.0 in c:\users\acer\downloads\linking-main (1)\linking-main\.venv\lib\site-packages (from stix2-patterns>=1.2.0->stix2->mitreattack-python) (4.9.3)
# Requirement already satisfied: cpe in c:\users\acer\downloads\linking-main (1)\linking-main\.venv\lib\site-packages (from stix2-validator>=3.0.0->stix2-elevator->mitreattack-python) (1.3.1)
# Requirement already satisfied: jsonschema>=4.20.0 in c:\users\acer\downloads\linking-main (1)\linking-main\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.20.0->stix2-validator>=3.0.0->stix2-elevator->mitreattack-python) (4.23.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\acer\downloads\linking-main (1)\linking-main\.venv\lib\site-packages (from jsonschema>=4.20.0->jsonschema[format-nongpl]>=4.20.0->stix2-validator>=3.0.0->stix2-elevator->mitreattack-python) (25.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\acer\downloads\linking-main (1)\linking-main\.venv\lib\site-packages (from jsonschema>=4.20.0->jsonschema[format-nongpl]>=4.20.0->stix2-validator>=3.0.0->stix2-elevator->mitreattack-python) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\acer\downloads\linking-main (1)\linking-main\.venv\lib\site-packages (from jsonschema>=4.20.0->jsonschema[format-nongpl]>=4.20.0->stix2-validator>=3.0.0->stix2-elevator->mitreattack-python) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\acer\downloads\linking-main (1)\linking-main\.venv\lib\site-packages (from jsonschema>=4.20.0->jsonschema[format-nongpl]>=4.20.0->stix2-validator>=3.0.0->stix2-elevator->mitreattack-python) (0.23.1)
# Requirement already satisfied: fqdn in c:\users\acer\downloads\linking-main (1)\linking-main\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.20.0->stix2-validator>=3.0.0->stix2-elevator->mitreattack-python) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\acer\downloads\linking-main (1)\linking-main\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.20.0->stix2-validator>=3.0.0->stix2-elevator->mitreattack-python) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\acer\downloads\linking-main (1)\linking-main\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.20.0->stix2-validator>=3.0.0->stix2-elevator->mitreattack-python) (3.0.0)
# Requirement already satisfied: rfc3339-validator in c:\users\acer\downloads\linking-main (1)\linking-main\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.20.0->stix2-validator>=3.0.0->stix2-elevator->mitreattack-python) (0.1.4)
# Requirement already satisfied: rfc3986-validator>0.1.0 in c:\users\acer\downloads\linking-main (1)\linking-main\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.20.0->stix2-validator>=3.0.0->stix2-elevator->mitreattack-python) (0.1.1)
# Requirement already satisfied: uri-template in c:\users\acer\downloads\linking-main (1)\linking-main\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.20.0->stix2-validator>=3.0.0->stix2-elevator->mitreattack-python) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\acer\downloads\linking-main (1)\linking-main\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.20.0->stix2-validator>=3.0.0->stix2-elevator->mitreattack-python) (24.11.1)
# Requirement already satisfied: ordered-set in c:\users\acer\downloads\linking-main (1)\linking-main\.venv\lib\site-packages (from mixbox>=1.0.4->stix<1.2.1.0,>=1.1.1.9->stix2-elevator->mitreattack-python) (4.1.0)
# Requirement already satisfied: weakrefmethod>=1.0.3 in c:\users\acer\downloads\linking-main (1)\linking-main\.venv\lib\site-packages (from mixbox>=1.0.4->stix<1.2.1.0,>=1.1.1.9->stix2-elevator->mitreattack-python) (1.0.3)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\acer\downloads\linking-main (1)\linking-main\.venv\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.20.0->stix2-validator>=3.0.0->stix2-elevator->mitreattack-python) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\acer\downloads\linking-main (1)\linking-main\.venv\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.20.0->stix2-validator>=3.0.0->stix2-elevator->mitreattack-python) (2.9.0.20241206)
# Note: you may need to restart the kernel to use updated packages.

# %%
import mitreattack.attackToExcel.attackToExcel as attackToExcel
import mitreattack.attackToExcel.stixToDf as stixToDf

# download and parse ATT&CK STIX data
attackdata = attackToExcel.get_stix_data("enterprise-attack")
techniques_data = stixToDf.techniquesToDf(attackdata, "enterprise-attack")

# show T1102 and sub-techniques of T1102
techniques_df = techniques_data["techniques"]
print(techniques_df[techniques_df["ID"].str.contains("T1102")]["name"])
# 512                                 Web Service
# 38     Web Service: Bidirectional Communication
# 121             Web Service: Dead Drop Resolver
# 323          Web Service: One-Way Communication
# Name: name, dtype: object

# show citation data for LOLBAS Wmic reference
citations_df = techniques_data["citations"]
print(citations_df[citations_df["reference"].str.contains("LOLBAS Wmic")])
#         reference                                           citation                                                url
# 1010  LOLBAS Wmic  LOLBAS. (n.d.). Wmic.exe. Retrieved July 31, 2...  https://lolbas-project.github.io/lolbas/Binari...
# Out:
# 2025-02-23 01:45:07.633 | INFO     | mitreattack.attackToExcel.attackToExcel:get_stix_data:69 - Downloading ATT&CK data from github.com/mitre/cti
# parsing techniques: 100%|██████████| 656/656 [00:00<00:00, 1499.68it/s]
# parsing relationships for type=technique: 100%|██████████| 19163/19163 [00:01<00:00, 15155.59it/s]
# 353                                 Web Service
# 483    Web Service: Bidirectional Communication
# 637             Web Service: Dead Drop Resolver
# 404          Web Service: One-Way Communication
# Name: name, dtype: object
#         reference                                           citation  \
# 1860  LOLBAS Wmic  LOLBAS. (n.d.). Wmic.exe. Retrieved July 31, 2...
#
#                                                     url
# 1860  https://lolbas-project.github.io/lolbas/Binari...

# %%
print(techniques_df.columns)
# Out:
# Index(['ID', 'STIX ID', 'name', 'description', 'url', 'created',
#        'last modified', 'domain', 'version', 'tactics', 'detection',
#        'platforms', 'data sources', 'is sub-technique', 'sub-technique of',
#        'defenses bypassed', 'contributors', 'permissions required',
#        'supports remote', 'system requirements', 'impact type',
#        'effective permissions', 'relationship citations'],
#       dtype='object')

# %%
techniques_df
# Out:
#             ID                                            STIX ID  \
# 279      T1548  attack-pattern--67720091-eee3-4d2d-ae16-826456...
# 55   T1548.002  attack-pattern--120d5519-3098-4e1c-9191-2aa612...
# 467  T1548.004  attack-pattern--b84903f0-c7d5-435d-a69e-de47cc...
# 281  T1548.001  attack-pattern--6831414d-bb70-42b7-8030-d4e06b...
# 58   T1548.003  attack-pattern--1365fe3b-0f50-455d-b4da-266ce3...
# ..         ...                                                ...
# 483  T1102.002  attack-pattern--be055942-6e63-49d7-9fa1-9cb7d8...
# 637  T1102.001  attack-pattern--f7827069-0bf2-4764-af4f-23fae0...
# 404  T1102.003  attack-pattern--9c99724c-a483-4d60-ad9d-7f004e...
# 5        T1047  attack-pattern--01a5a209-b94c-450b-b7f9-946497...
# 604      T1220  attack-pattern--ebbe170d-aa74-4946-8511-992124...
#
#                                                   name  \
# 279                  Abuse Elevation Control Mechanism
# 55   Abuse Elevation Control Mechanism: Bypass User...
# 467  Abuse Elevation Control Mechanism: Elevated Ex...
# 281  Abuse Elevation Control Mechanism: Setuid and ...
# 58   Abuse Elevation Control Mechanism: Sudo and Su...
# ..                                                 ...
# 483           Web Service: Bidirectional Communication
# 637                    Web Service: Dead Drop Resolver
# 404                 Web Service: One-Way Communication
# 5                   Windows Management Instrumentation
# 604                              XSL Script Processing
#
#                                            description  \
# 279  Adversaries may circumvent mechanisms designed...
# 55   Adversaries may bypass UAC mechanisms to eleva...
# 467  Adversaries may leverage the <code>Authorizati...
# 281  An adversary may abuse configurations where an...
# 58   Adversaries may perform sudo caching and/or us...
# ..                                                 ...
# 483  Adversaries may use an existing, legitimate ex...
# 637  Adversaries may use an existing, legitimate ex...
# 404  Adversaries may use an existing, legitimate ex...
# 5    Adversaries may abuse Windows Management Instr...
# 604  Adversaries may bypass application control and...
#
#                                                url          created  \
# 279      https://attack.mitre.org/techniques/T1548  30 January 2020
# 55   https://attack.mitre.org/techniques/T1548/002  30 January 2020
# 467  https://attack.mitre.org/techniques/T1548/004  30 January 2020
# 281  https://attack.mitre.org/techniques/T1548/001  30 January 2020
# 58   https://attack.mitre.org/techniques/T1548/003  30 January 2020
# ..                                             ...              ...
# 483  https://attack.mitre.org/techniques/T1102/002    14 March 2020
# 637  https://attack.mitre.org/techniques/T1102/001    14 March 2020
# 404  https://attack.mitre.org/techniques/T1102/003    14 March 2020
# 5        https://attack.mitre.org/techniques/T1047      31 May 2017
# 604      https://attack.mitre.org/techniques/T1220  17 October 2018
#
#          last modified             domain version  \
# 279    15 October 2024  enterprise-attack     1.4
# 55       21 April 2023  enterprise-attack     2.1
# 467    19 October 2022  enterprise-attack     1.0
# 281      15 March 2023  enterprise-attack     1.1
# 58       14 March 2022  enterprise-attack     1.0
# ..                 ...                ...     ...
# 483      26 March 2020  enterprise-attack     1.0
# 637      26 March 2020  enterprise-attack     1.0
# 404      26 March 2020  enterprise-attack     1.0
# 5      15 October 2024  enterprise-attack     1.5
# 604  12 September 2024  enterprise-attack     1.2
#
#                                    tactics  ... is sub-technique  \
# 279  Defense Evasion, Privilege Escalation  ...            False
# 55   Defense Evasion, Privilege Escalation  ...             True
# 467  Defense Evasion, Privilege Escalation  ...             True
# 281  Defense Evasion, Privilege Escalation  ...             True
# 58   Defense Evasion, Privilege Escalation  ...             True
# ..                                     ...  ...              ...
# 483                    Command and Control  ...             True
# 637                    Command and Control  ...             True
# 404                    Command and Control  ...             True
# 5                                Execution  ...            False
# 604                        Defense Evasion  ...            False
#
#     sub-technique of                                  defenses bypassed  \
# 279              NaN                                                NaN
# 55             T1548                       Windows User Account Control
# 467            T1548                                                NaN
# 281            T1548                                                NaN
# 58             T1548                                                NaN
# ..               ...                                                ...
# 483            T1102                                                NaN
# 637            T1102                                                NaN
# 404            T1102                                                NaN
# 5                NaN                                                NaN
# 604              NaN  Anti-virus, Application Control, Digital Certi...
#
#                                           contributors permissions required  \
# 279                                                NaN  Administrator, User
# 55                         Casey Smith; Stefan Kanthak  Administrator, User
# 467  Erika Noerenberg, @gutterchurl, Carbon Black; ...  Administrator, User
# 281                                                NaN                 User
# 58                                                 NaN                 User
# ..                                                 ...                  ...
# 483                                                NaN                 User
# 637                                                NaN                 User
# 404                                                NaN                 User
# 5    @ionstorm; Olaf Hartong, Falcon Force; Tristan...                  NaN
# 604              Avneet Singh; Casey Smith; Praetorian                  NaN
#
#     supports remote                                system requirements  \
# 279             NaN                                                NaN
# 55              NaN                                                NaN
# 467             NaN                                                NaN
# 281             NaN                                                NaN
# 58              NaN                                                NaN
# ..              ...                                                ...
# 483             NaN                                                NaN
# 637             NaN                                                NaN
# 404             NaN                                                NaN
# 5              True                                                NaN
# 604             NaN  Microsoft Core XML Services (MSXML) or access ...
#
#     impact type effective permissions  \
# 279         NaN                   NaN
# 55          NaN         Administrator
# 467         NaN                  root
# 281         NaN                   NaN
# 58          NaN                  root
# ..          ...                   ...
# 483         NaN                   NaN
# 637         NaN                   NaN
# 404         NaN                   NaN
# 5           NaN                   NaN
# 604         NaN                   NaN
#
#                                 relationship citations
# 279  (Citation: TrendMicro RaspberryRobin 2022),(Ci...
# 55   (Citation: Microsoft BlackCat Jun 2022),(Citat...
# 467         (Citation: Carbon Black Shlayer Feb 2019),
# 281  (Citation: ANSSI Sandworm January 2021),(Citat...
# 58   (Citation: Cobalt Strike Manual 4.3 November 2...
# ..                                                 ...
# 483  (Citation: ESET Dukes October 2019),(Citation:...
# 637  (Citation: ESET Dukes October 2019),(Citation:...
# 404  (Citation: FireEye Periscope March 2018),(Cita...
# 5    (Citation: DFIR Conti Bazar Nov 2021),(Citatio...
# 604  (Citation: Talos Cobalt Group July 2018),(Cita...
#
# [656 rows x 23 columns]

# %%
techniques_df.to_excel("techniques.xlsx", index=False)

# %%
import pandas as pd
cvedata=pd.read_excel("cve_cwe_mitre_mapped.xlsx")
cvedata = cvedata.dropna(subset=["MITRE_Technique"])
print(cvedata.head())
cvedata.to_excel("processed_cve_data.xlsx", index=False)
# Out:
#           CVE_ID   CWE_ID                                    MITRE_Technique  \
# 0  CVE-1999-0509   CWE-94  1027.006 - Obfuscated Files or Information: HT...
# 3  CVE-1999-0236  CWE-200  1562.003 - Impair Defenses:Impair Command Hist...
# 4  CVE-1999-0236  CWE-200  1217 - Browser Bookmark Discovery; 1592 - Gath...
# 5  CVE-1999-0236  CWE-200                     1018 - Remote System Discovery
# 6  CVE-1999-0236  CWE-200                       1124 - System Time Discovery
#
#                                      CVE_Description  \
# 0  Perl, sh, csh, or other shell interpreters are...
# 3  ScriptAlias directory in NCSA and Apache httpd...
# 4  ScriptAlias directory in NCSA and Apache httpd...
# 5  ScriptAlias directory in NCSA and Apache httpd...
# 6  ScriptAlias directory in NCSA and Apache httpd...
#
#                                      CWE_Description  CVSS_Base_Score  \
# 0  The product constructs all or part of a code s...             10.0
# 3  The product exposes sensitive information to a...              7.5
# 4  The product exposes sensitive information to a...              7.5
# 5  The product exposes sensitive information to a...              7.5
# 6  The product exposes sensitive information to a...              7.5
#
#   Confidentiality_Impact Integrity_Impact Availability_Impact
# 0               COMPLETE         COMPLETE            COMPLETE
# 3                   HIGH             NONE                NONE
# 4                   HIGH             NONE                NONE
# 5                   HIGH             NONE                NONE
# 6                   HIGH             NONE                NONE
